# %%
# Out:
# 吃吃吃只知道吃!
#
# 位置：前門請輸入 MG ;後門請輸入 118; 公館請輸入 GG 公館前門輸入 GGEn
# 價錢：100以下輸入1 ; 100~200輸入2 ; 200~300輸入3 ; 300以上輸入 I am rich ; 隨便以上輸入 Whatever ; 不想付錢輸入 0
# 位置GG
# 價錢2
# ['車輪餅,珍奶']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-99ac5a1ba5c9> in <module>
#      70     print ('error1')
#      71
# ---> 72 print( random.sample (food,k=1))
#
# NameError: name 'food' is not defined

# %%
import numpy as np
import random
import webbrowser

   
#前門
MG_1 = ["雲香亭" ," 泰街頭" ,"阿英滷肉飯" , "鳳城燒臘",'溏老鴨','韓庭州','彩椒廚房','貳食柒','麥子磨麵','小飯廳']
MG_2 = ["左巴好室","雀兒小餐館",'大盛豬排','瑪莉珍','kitchen66']
MG_3 = ["鼎太極"]
MG_rich = ["從缺,別說這個了如果你是正咩的話缺男友嗎？"]
MG_all=MG_1+MG_2+MG_3+MG_rich
#118巷
S118_1 = ["南台虱目魚",'阿英海產粥','韓喜堂','忠誠山東蔥油餅','蔥燉牛肉麵','山西刀削麵館','一極拌福州乾拌麵館','笑嘻嘻','靚咖哩','紫牛','滇味小館','阿忠麵店(地圖上沒有haha)','大李水餃','松田日式飯糰']
S118_2 = ["微笑廚房洋食館",'Blue磚塊義法廚房','河內美食 （Hanoi Food)','邦食堂','正香海南雞飯','米多麗小館','The Sandrich House','我家吃麵','找碗','二八麵堂','']
S118_12=S118_1+S118_2
S118_3 = ["目前沒有QQ"]
S118_rich = ['你有病吧118哪有這麼貴的']
S118_all=S118_1+S118_2+S118_3+S118_rich
#公館
GG_1=['大水源','曼谷燒','薩莉亞','麥當勞','季丼屋','直火人丼飯','藍家割包','水源市場 水餃','大學口臭豆腐','白帝城川式滷味','Mr.拉麵']
GG_2=['池先生','阿里媽媽','鍋in','小飯兒館','泰國小館','初牛','靜壽司','Bravo發福廚房','赤神豬排','狂愛咖哩','韓天閣']
GG_3=['山嵐拉麵','右手餐廳','狗一下','鷹流拉麵']
GG_rich=['易牙居','馬辣']
GG_all=GG_1+GG_2+GG_3+GG_rich
#公館前門
GGEn_1=MG_1+GG_1
GGEn_2=MG_2+GG_2
GGEn_3=MG_3+GG_3
GGEn_rich=GG_rich+MG_rich
GGEn_all=GGEn_1+GGEn_2+GGEn_3+GGEn_rich
#甜點
Dessert=['chez nous','Mr.雪腐','波囍','The Common','土司吐司','倆倆號','龍泉豆花','鴉片粉圓','IC AIRPORT','陳三鼎','貳樓餐廳','咪莉奶奶餅乾','Coco Brownies','好想吃冰','70-1 sweet to go','Quichez派出所','後門果汁阿姨','春山茶水']
#咖啡
Coffee=['flügel studio','湛盧咖啡','路燈咖啡','Ville Cafe','法語人之家','小公館cafe','感恩小館','AGCT Apartment','Cafe Bastille','女巫店','L‘amour','imperfect coffee',"雀兒小餐館",'片場咖啡','野餐咖啡','歐克法']
#吃土的
poormouth=['回家喝奶拉','牢飯','土','西北風']
FF=['ಠ_ಠ','( ͡° ͜ʖ ͡°)','凸(= _=)凸','(ﾟДﾟ≡ﾟДﾟ)?','( ﾟДﾟ)ﾉ⌒⑤','(σ´□｀)σσσσσσσ','(゜o゜(☆○=(-_- )','(((┏(;￣▽￣)┛']

print('歡迎使用選擇性障礙輔助器8.7 \n但不是我要說你 吃吃吃只會吃,還選不出來 真慘！ ')
print ("\n位置：前門請輸入:MG  後門請輸入:118  公館請輸入:GG 公館前門輸入:GGEn \n位置_特殊選項:甜點輸入:DE 咖啡輸入:CO 價錢處隨便輸入即可\n價錢：150以下輸入:1 ; 150~300輸入:2 ; 300~400輸入:3 ; 400以上輸入: I am rich ; 隨便以上輸入:Whatever ; 不想付錢輸入 0 ")

x=input('\n位置')
p=input('價錢分區')
while True :

 

    if x=='MG' and p=='1' :
        food=MG_1
    elif x=='MG' and p=='2' :
        food=MG_2
    elif x=='MG' and p=='3' :
        food=MG_3
    elif x=='MG' and p=='I am rich' :
        food=MG_rich
    elif x=='MG' and p=='Whatever' :
        food=MG_all
    elif x=='118' and p=='1' :
        food=S118_12
    elif x=='118' and p=='2' :
        food=S118_12
    elif x=='118' and p=='3' :
        food=S118_3
    elif x=='118' and p=='I am rich' :
        food=S118_rich
    elif x=='118' and p=='Whatever' :
        food=S118_all
    elif x=='GG' and p=='1' :
        food=GG_1
    elif x=='GG' and p=='2' :
        food=GG_2
    elif x=='GG' and p=='3' :
        food=GG_3
    elif x=='GG' and p=='I am rich' :
        food=GG_rich
    elif x=='GG' and p=='Whatever' :
        food=GG_all
    elif x=='GGEn' and p=='1' :
        food=GGEn_1
    elif x=='GGEn' and p=='2' :
        food=GGEn_2
    elif x=='GGEn' and p=='3' :
        food=GGEn_3
    elif x=='GGEn' and p=='I am rich' :
        food=GGEn_rich
    elif x=='GGEn' and p=='Whatever' :
        food=GGEn_all
    elif x=='DE' : 
        food=Dessert
    elif x=='CO' :
        food=Coffee
    elif p=='0':
        food=poormouth
    else :
        print ('error1')
        
    #由符合條件的群隨機選取
    m=random.sample (food,k=1)
    
    print(m)
    print('\n輸入y結束並開啟地圖\n輸入no thx直接結束\n不滿意可以按任意鍵重選')
    say= input('你的選擇')
   
    if say=='y':#for while
        print ('\n甲霸緊睏')
        #開啟網站,mac版本設定以google chrome 開啟
        
        restaurant =m[0]#由於m為list,而開網站需要字串故取自串的第一個數
        
        #print(type(m)) #測試用看m的資料型態
        
        restaurant_map='https://www.google.com.tw/maps/search/'+restaurant
        webbrowser.get("open -a /Applications/Google\ Chrome.app %s").open(restaurant_map) #for mac
        #webbrowser.open_new_tab(restaurant_map) #for wandows
        break
    elif say=='no thx': #for while
        print('\n虧我還用了那個地圖連結\n我被你擊敗了,你是擊敗人')
        break

del say
del food

#在此特別感謝冠銘學長幫我解決BUG
#此美食大部分是由吃貨台大收錄

# %%
import numpy as np
import random
import webbrowser
from ipywidgets import interact 


    #print('歡迎使用選擇性障礙輔助器8.7 \n但不是我要說你 吃吃吃只會吃,還選不出來 真慘！ ')
print ("\nLocation：前門:MG  後門:118  公館:GG 公館&前門:GGEn \n\nLoaction_speical:甜點:DE 咖啡:CO,*甜點與咖啡沒分地點 ") 
    #z= input('1')

def f1(location=' ',price=' ',google_map=' '):
                food=['快點選拉']
                
    #print(x,y)    
    #if z =='yes':
            #x=input('\n位置')
            #p=input('價錢分區')
    #while True :

                if location=='MG' and price=='150 or under' :
                    food=MG_1
                elif location=='MG' and price=='150-300' :
                    food=MG_2
                elif location=='MG' and price=='300-450' :
                    food=MG_3
                elif location=='MG' and price=='over_450 ( I am rich )' :
                    food=MG_rich
                elif location=='MG' and price=='All is good' :
                    food=MG_all
                elif location=='118' and price=='150 or under' :
                    food=S118_12
                elif location=='118' and price=='150-300' :
                    food=S118_12
                elif location=='118' and price=='300-450' :
                    food=S118_3
                elif location=='118' and price=='over_450 ( I am rich )' :
                    food=S118_rich
                elif location=='118' and price=='All is good' :
                    food=S118_all
                elif location=='GG' and price=='150 or under' :
                    food=GG_1
                elif location=='GG' and price=='150-300' :
                    food=GG_2
                elif location=='GG' and price=='300-450' :
                    food=GG_3
                elif location=='GG' and price=='over_450 ( I am rich )' :
                    food=GG_rich
                elif location=='GG' and price=='All is good' :
                    food=GG_all
                elif location=='GGEn' and price=='150 or under' :
                    food=GGEn_1
                elif location=='GGEn' and price=='150-300' :
                    food=GGEn_2
                elif location=='GGEn' and price=='300-450' :
                    food=GGEn_3
                elif location=='GGEn' and price=='over_450 ( I am rich )' :
                    food=GGEn_rich
                elif location=='GGEn' and price=='All is good' :
                    food=GGEn_all
                elif location=='DE' : 
                    food=Dessert
                elif location=='CO' :
                    food=Coffee
                elif price=='eat the bread of idleness':
                    food=poormouth
                else :
                    print (' ')

                #由符合條件的群隨機選取
                m=random.sample (food,k=1)
                
                print('幫您選擇的餐廳：')
                print(m)
                print('   _________\n   | へ    へ |  \n   | のもの“|\n   \   へ   / \n     \____/')
                #print('\n輸入y結束並開啟地圖\n輸入no thx直接結束\n不滿意可以按任意鍵重選')
               # say= input('你的選擇')

                if google_map=='switch on':#for while
                    print ('\n甲霸緊睏')
                    #開啟網站,mac版本設定以google chrome 開啟

                    restaurant =m[0]#由於m為list,而開網站需要字串故取自串的第一個數

                    #print(type(m)) #測試用看m的資料型態

                    restaurant_map='https://www.google.com.tw/maps/search/'+restaurant
                    webbrowser.get("open -a /Applications/Google\ Chrome.app %s").open(restaurant_map) #for mac
                    #webbrowser.open_new_tab(restaurant_map) #for wandows
                    #break
                elif google_map=='no thx': #for while
                    print('\n我被你擊敗了,你是擊敗人\n虧我還用了那個地圖連結')
                   # break
                else:
                    print(' ')

interact(f1,location=['請選擇','MG','118','GG','GGEn','DE','CO'],price=['請選擇','150 or under','150-300','300-450','over_450 ( I am rich )','all is good','eat the bread of idleness'],google_map=['請選擇','switch on','no thx','GG']) ; #下拉式選單 
#interact(f,x=['請選擇','1','2','3']) #下拉式選單
# Out:
# Location：前門:MG  後門:118  公館:GG 公館&前門:GGEn
#
# Loaction_speical:甜點:DE 咖啡:CO,*甜點與咖啡沒分地點
# interactive(children=(Dropdown(description='location', options=('請選擇', 'MG', '118', 'GG', 'GGEn', 'DE', 'CO'),…

# %%
import numpy as np
import random
import webbrowser
from ipywidgets import interact 
from IPython.display import clear_output
import time

print('歡迎使用選擇性障礙輔助器2.0 ')
print ("\nLocation：前門:MG  後門:118  公館:GG 公館&前門:GGEn \n\nLoaction_speical:甜點:DE 咖啡:CO,*甜點與咖啡沒分地點 ") 
print("不趕時間的話 fun可以選 free ")
def f(fun=' '):
        
        
        if fun==1:
            def f1(location=' ',price=' ',google_map=' '):
                        food=['快點選拉']
                    
                        if location=='MG' and price=='150 or under' :
                            food=MG_1
                        elif location=='MG' and price=='150-300' :
                            food=MG_2
                        elif location=='MG' and price=='300-450' :
                            food=MG_3
                        elif location=='MG' and price=='over_450 ( I am rich )' :
                            food=MG_rich
                        elif location=='MG' and price=='All is good' :
                            food=MG_all
                        elif location=='118' and price=='150 or under' :
                            food=S118_12
                        elif location=='118' and price=='150-300' :
                            food=S118_12
                        elif location=='118' and price=='300-450' :
                            food=S118_3
                        elif location=='118' and price=='over_450 ( I am rich )' :
                            food=S118_rich
                        elif location=='118' and price=='All is good' :
                            food=S118_all
                        elif location=='GG' and price=='150 or under' :
                            food=GG_1
                        elif location=='GG' and price=='150-300' :
                            food=GG_2
                        elif location=='GG' and price=='300-450' :
                            food=GG_3
                        elif location=='GG' and price=='over_450 ( I am rich )' :
                            food=GG_rich
                        elif location=='GG' and price=='All is good' :
                            food=GG_all
                        elif location=='GGEn' and price=='150 or under' :
                            food=GGEn_1
                        elif location=='GGEn' and price=='150-300' :
                            food=GGEn_2
                        elif location=='GGEn' and price=='300-450' :
                            food=GGEn_3
                        elif location=='GGEn' and price=='over_450 ( I am rich )' :
                            food=GGEn_rich
                        elif location=='GGEn' and price=='All is good' :
                            food=GGEn_all
                        elif location=='DE' : 
                            food=Dessert
                        elif location=='CO' :
                            food=Coffee
                        elif price=='eat the bread of idleness':
                            food=poormouth
                        else :
                            print (' ')

                        #由符合條件的群隨機選取
                        m=random.sample (food,k=1)

                        print('幫您選擇的餐廳：')
                        print(m)
                        print('   _________\n   | へ    へ |  \n   | のもの“|\n   \   へ   / \n     \____/')
                      
                        if google_map=='switch on':#for while
                            print ('\n甲霸緊睏')
                            #開啟網站,mac版本設定以google chrome 開啟

                            restaurant =m[0]#由於m為list,而開網站需要字串故取自串的第一個數

                            #print(type(m)) #測試用看m的資料型態

                            restaurant_map='https://www.google.com.tw/maps/search/'+restaurant
                            webbrowser.get("open -a /Applications/Google\ Chrome.app %s").open(restaurant_map) #for mac
                            #webbrowser.open_new_tab(restaurant_map) #for wandows
                            #break
                        elif google_map=='no thx': #for while
                            print('\n我被你擊敗了,你是擊敗人\n虧我還用了那個地圖連結')
                           # break
                        else:
                            print(' ')
        if fun==2:
                    emoticon ='(((┏(;￣▽￣)┛DWJS'
                    emoticon1 ='(((┏(;￣▽￣)┛'
                    emoticon2='(ﾟﾛ ﾟﾉ)ﾉ'
                    emoticon3='X▃X'
                    emoticon4 ='(ｏ￣∇￣)＝◯)`ν゜)･；`'
                    emoticon5 ='V)(́◉◞౪◟◉‵)(V)'
                    emoticon6='((┏(́墨◞౪◟鏡‵)┛'
                    emoticon7='(╯◕◞౪◟◕‵)╯︵ ┴─┴'

                    for i in range(5):
                        k = i
                        sp =  k

                        clear_output(wait=True)

                        print(' '*sp +emoticon)
                        print('DWJS=擋我者死')
                        time.sleep(0.5)
                    for i in range(3): 
                        k = i*5+20
                        sp=k
                        clear_output(wait=True)
                        print(' '*sp +emoticon1,emoticon2)
                        print('DWJS=擋我者死')
                        time.sleep(0.5)
                    for i in range(5):
                        k = i*5+35
                        sp = k
                        clear_output(wait=True)
                        print(' '*k+emoticon4)
                        time.sleep(0.5)
                    for i in range(3):
                        k = i*5+5
                        sp = k
                        clear_output(wait=True)
                        print(' '*60+emoticon3,' '*sp +emoticon5)
                        time.sleep(0.5)
                    for i in range(3):
                        k = i*5+90
                        sp = k
                        clear_output(wait=True)
                        print(' '*sp +emoticon1)
                        time.sleep(0.5)
                    for i in range(5):
                        k = i*5+105
                        sp = k
                        clear_output(wait=True)
                        print(' '*sp +emoticon6)
                        time.sleep(0.5)
                    for i in range(5):
                        k = i*5+105
                        sp = k
                        clear_output(wait=True)
                        print(' '*120 +emoticon7)
                        time.sleep(1)
                    clear_output(wait=True)
            
                       

        interact(f1,location=['請選擇','MG','118','GG','GGEn','DE','CO'],price=['請選擇','150 or under','150-300','300-450','over_450 ( I am rich )','all is good','eat the bread of idleness'],google_map=['請選擇','switch on','no thx','GG']) ; #下拉式選單 
interact(f, fun={'no':1, 'of course':2}) #下拉式選單
# Out:
# 歡迎使用選擇性障礙輔助器2.0
#
# Location：前門:MG  後門:118  公館:GG 公館&前門:GGEn
#
# Loaction_speical:甜點:DE 咖啡:CO,*甜點與咖啡沒分地點
# 不趕時間的話 fun可以選 free
# interactive(children=(Dropdown(description='fun', options={'no': 1, 'of course': 2}, value=1), Output()), _dom…
# <function __main__.f(fun=' ')>

# %%
widgets.Button(
    description='Click me',
    disabled=False,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click me',
    icon='check')


# 调整按钮
from ipywidgets import Button, Layout

b = Button(description='(50% width, 80px height) button',
           layout=Layout(width='50%', height='80px'),
          button_style='success')
#print(b)


#def f(x):
   # interact(f, x=True);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-851d89137688> in <module>
# ----> 1 widgets.Button(
#       2     description='Click me',
#       3     disabled=False,
#       4     button_style='success', # 'success', 'info', 'warning', 'danger' or ''
#       5     tooltip='Click me',
#
# NameError: name 'widgets' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.patches import Ellipse, Circle
from colorama import Fore, Back, Style 
def BMI(height, weight):
#'''BMI(height, weight), 輸入 身高, 體重, 回傳 BMI'''
    code = 0
    dicts = {0:'none', 1:'體重過輕', 2:'健康體位', 4:'(過重)', 5:'(輕度肥胖)', 6:'(中度肥胖)', 7:'(重度肥胖)'}
    val = weight/pow(height/100, 2)
    if val < 18.5: 
        code = 1
        print(Fore.YELLOW)
    elif 18.5 <= val < 24:
        code = 2
        print(Fore.GREEN) 
    else:
        print(Fore.RED)
    if 24 <= val < 27:
        code = 4
    elif 27 <= val < 30:
        code = 5
    elif 30 <= val < 35:
        code = 6
    elif val >= 35:
        code = 7
        print(f'您的 BMI 是 {val:.1f}，屬於 ' + dicts[code]) 
    ''''BMIG(code)
def BMIG(code):
    BMIG(w, h), 輸入 寬, 高, 回傳 圓圖示
    w = 100
    if code == 1: 
        h = 10
        c = 'yellow'
    elif code == 2:
        h = 100
        c = 'green'
    else:
        c = 'red'
        h = 100
    if code == 4:
        w = 10 
    elif code == 5:
        w = 30
    elif code == 6:
        w = 50
    elif code == 7:
        w = 70 
    ax = plt.figure().add_subplot(111)
    ax.add_patch(Ellipse(xy = (0, 0), width = w, height = h, angle = 90, facecolor= c, alpha=0.5))
    ax.plot(0, 0, 'ro')
    plt.axis('scaled')
    plt.show()
    from ipywidgets import interact
    print('請選擇您的身高及體重，檢測 BMI')'''
    interact(BMI, height=(100, 190), weight=(40, 120))

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-be45ee4cfc3e> in <module>
#       2 import random
#       3 import webbrowser
# ----> 4 str.decode(encoding='UTF-8',errors='strict')
#       5 x=input('位置')
#       6 p=input('價錢')
#
# AttributeError: type object 'str' has no attribute 'decode'

# %%
# Out:
# 台大
# True

# %%
s='aaaa'
s2=repr(s)
print(s2)
l=""
for i in range(len(s2)):
    if s2[i]!="'":
        l+=s2[i]
print(l)
# Out:
# 'aaaa'
# aaaa

# %%
                        emoticon ='(((┏(;￣▽￣)┛DWJS'
                        emoticon1 ='(((┏(;￣▽￣)┛'
                        emoticon2='(ﾟﾛ ﾟﾉ)ﾉ'
                        emoticon3='X▃X'
                        emoticon4 ='(ｏ￣∇￣)＝◯)`ν゜)･；`'
                        emoticon5 ='V)(́◉◞౪◟◉‵)(V)'
                        emoticon6='((┏(́墨◞౪◟鏡‵)┛'
                        emoticon7='(╯◕◞౪◟◕‵)╯︵ ┴─┴'
                        for i in range(5):
                            k = i
                            sp =  k
                           
                            clear_output(wait=True)
                           
                            print(' '*sp +emoticon)
                            print('DWJS=擋我者死')
                            time.sleep(0.5)
                        for i in range(3): 
                            k = i*5+20
                            sp=k
                            clear_output(wait=True)
                            print(' '*sp +emoticon1,emoticon2)
                            print('DWJS=擋我者死')
                            time.sleep(0.5)
                        for i in range(5):
                            k = i*5+35
                            sp = k
                            clear_output(wait=True)
                            print(' '*k+emoticon4)
                            time.sleep(0.5)
                        for i in range(3):
                            k = i*5+5
                            sp = k
                            clear_output(wait=True)
                            print(' '*60+emoticon3,' '*sp +emoticon5)
                            time.sleep(0.5)
                        for i in range(3):
                            k = i*5+90
                            sp = k
                            clear_output(wait=True)
                            print(' '*sp +emoticon1)
                            time.sleep(0.5)
                        for i in range(5):
                            k = i*5+105
                            sp = k
                            clear_output(wait=True)
                            print(' '*sp +emoticon6)
                            time.sleep(0.5)
                        clear_output(wait=True)
                        sp=130
                        print(' '*sp +emoticon7)
                        time.sleep(1)
                        clear_output(wait=True)
# Out:
#                                                                                                                                   (╯◕◞౪◟◕‵)╯︵ ┴─┴

# %%
import sys
print(sys.getdefaultencoding())
s='台大'
s='https://www.google.com.tw/maps/search/'+s
#s = s.encode('GBK')
#s = str(s)
print(s)
#print(s, type(s))
import webbrowser
#開啟網站,mac版本設定以google chrome 開啟
webbrowser.get("open -a /Applications/Google\ Chrome.app %s").open("http://google.com") #for mac
webbrowser.open_new_tab(s) #for wandows
# Out:
# utf-8
# https://www.google.com.tw/maps/search/台大
# True

# %%
print('   _________\n   | へ    へ |  \n   | のもの“|\n   \   へ   / \n     \____/')
# Out:
#    _________
#    | へ    へ |
#    | のもの“|
#    \   へ   /
#      \____/

# %%
# Out:
#                隊伍        勝率     贏面
# 0         Atlanta  1.000000   True
# 1          Boston  0.666667  False
# 2        Brooklyn  1.000000   True
# 3         Chicago  1.000000   True
# 4       Charlotte  0.750000   True
# 5       Cleveland  1.000000   True
# 6          Dallas  1.000000   True
# 7          Denver  1.000000   True
# 8         Detroit  1.000000   True
# 9    Golden State  0.500000  False
# 10        Houston  1.000000   True
# 11        Indiana  0.750000   True
# 12    LA Clippers  0.000000  False
# 13      LA Lakers  1.000000   True
# 14        Memphis  0.500000  False
# 15          Miami  0.666667  False
# 16      Minnesota  1.000000   True
# 17    New Orleans  1.000000   True
# 18       New York  0.750000   True
# 19  Oklahoma City  0.000000  False
# 20        Orlando  0.666667  False
# 21   Philadelphia  0.500000  False
# 22        Phoenix  0.000000  False
# 23       Portland  0.500000  False
# 24     Sacramento  1.000000   True
# 25    San Antonio  0.500000  False
# ...

# %%
C=(L>0.7)
C
# Out:
# array([[ True, False,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True, False,  True, False, False,  True,  True,
#          True, False, False, False, False, False,  True, False,  True,
#         False, False]])

# %%
C
# Out:
# array([[ True, False,  True,  True,  True,  True,  True,  True,  True,
#         False,  True,  True, False,  True, False, False,  True,  True,
#          True, False, False, False, False, False,  True, False,  True,
#         False, False]])
